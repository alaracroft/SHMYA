# %%
from scipy import stats as st
import numpy as np
import math as mth

#Нулевая гипотеза - конверсии равны
# Альтернативная гипотеза - конверсии не равны

for i in range(1, 3050): 
    alpha = .05 # критический уровень статистической значимости

    successes = np.array([i,i*3050/3200*1.05])
    trials = np.array([3200, 3050])

# пропорция успехов в первой группе:
    p1 = successes[0]/trials[0]

# пропорция успехов во второй группе:
    p2 = successes[1]/trials[1]

# пропорция успехов в комбинированном датасете:
    p_combined = (successes[0] + successes[1]) / (trials[0] + trials[1])

# разница пропорций в датасетах
    difference = p1 - p2 
    z_value = difference / mth.sqrt(
    p_combined * (1 - p_combined) * (1 / trials[0] + 1 / trials[1])
)

# задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
    distr = st.norm(0, 1)

    p_value = (1 - distr.cdf(abs(z_value))) * 2
    print(i)
    print('p-значение: ', p_value)

    if p_value < alpha:
        print('Отвергаем нулевую гипотезу: между долями есть значимая разница')
    else:
        print(
        'Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными'
    )
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# p-значение:  0.08557932534240575
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1384
# p-значение:  0.08537644695668378
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1385
# p-значение:  0.08517385620869189
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1386
# p-значение:  0.08497155298437375
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1387
# p-значение:  0.08476953716973123
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1388
# p-значение:  0.0845678086508237
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1389
# p-значение:  0.08436636731376601
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1390
# p-значение:  0.08416521304472746
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1391
# p-значение:  0.08396434572993261
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1392
# p-значение:  0.08376376525565687
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1393
# p-значение:  0.08356347150822785
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1394
# p-значение:  0.08336346437402353
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1395
# p-значение:  0.083163743739465
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1396
# p-значение:  0.08296430949102818
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1397
# p-значение:  0.08276516151522917
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1398
# p-значение:  0.08256629969863072
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1399
# p-значение:  0.08236772392784064
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1400
# p-значение:  0.08216943408950339
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1401
# p-значение:  0.08197143007030916
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1402
# p-значение:  0.08177371175698567
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1403
# p-значение:  0.08157627903629838
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1404
# p-значение:  0.08137913179505296
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1405
# p-значение:  0.08118226992008526
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1406
# p-значение:  0.08098569329826755
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1407
# p-значение:  0.08078940181650673
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1408
# p-значение:  0.08059339536174015
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1409
# p-значение:  0.08039767382093665
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1410
# p-значение:  0.08020223708109175
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1411
# p-значение:  0.0800070850292316
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1412
# p-значение:  0.07981221755240764
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1413
# p-значение:  0.07961763453769799
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1414
# p-значение:  0.07942333587220318
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1415
# p-значение:  0.0792293214430464
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1416
# p-значение:  0.0790355911373739
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1417
# p-значение:  0.07884214484235219
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1418
# p-значение:  0.07864898244516572
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1419
# p-значение:  0.07845610383301826
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1420
# p-значение:  0.07826350889312739
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1421
# p-значение:  0.07807119751272928
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1422
# p-значение:  0.07787916957907104
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1423
# p-значение:  0.07768742497941417
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1424
# p-значение:  0.07749596360103239
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1425
# p-значение:  0.077304785331207
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1426
# p-значение:  0.07711389005723035
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1427
# p-значение:  0.07692327766640195
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1428
# p-значение:  0.0767329480460277
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1429
# p-значение:  0.07654290108341932
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1430
# p-значение:  0.07635313666589094
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1431
# p-значение:  0.07616365468075936
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1432
# p-значение:  0.07597445501534383
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1433
# p-значение:  0.07578553755696404
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1434
# p-значение:  0.07559690219293813
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1435
# p-значение:  0.07540854881058023
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1436
# p-значение:  0.07522047729720316
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1437
# p-значение:  0.07503268754011394
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1438
# p-значение:  0.07484517942661384
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1439
# p-значение:  0.07465795284399657
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1440
# p-значение:  0.07447100767954473
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1441
# p-значение:  0.07428434382053495
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1442
# p-значение:  0.07409796115423006
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1443
# p-значение:  0.07391185956788315
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1444
# p-значение:  0.07372603894873264
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1445
# p-значение:  0.07354049918399874
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1446
# p-значение:  0.07335524016089012
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1447
# p-значение:  0.07317026176659525
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1448
# p-значение:  0.07298556388828548
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1449
# p-значение:  0.07280114641311286
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1450
# p-значение:  0.07261700922820524
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1451
# p-значение:  0.07243315222067159
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1452
# p-значение:  0.07224957527759557
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1453
# p-значение:  0.07206627828603662
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1454
# p-значение:  0.07188326113302823
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1455
# p-значение:  0.07170052370557611
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1456
# p-значение:  0.07151806589065623
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1457
# p-значение:  0.07133588757521747
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1458
# p-значение:  0.07115398864617606
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1459
# p-значение:  0.07097236899041692
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1460
# p-значение:  0.07079102849478969
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1461
# p-значение:  0.07060996704611089
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1462
# p-значение:  0.07042918453116132
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1463
# p-значение:  0.07024868083668379
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1464
# p-значение:  0.0700684558493827
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1465
# p-значение:  0.06988850945592229
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1466
# p-значение:  0.069708841542927
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1467
# p-значение:  0.06952945199697891
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1468
# p-значение:  0.06935034070461676
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1469
# p-значение:  0.0691715075523347
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1470
# p-значение:  0.06899295242658021
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1471
# p-значение:  0.06881467521375528
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1472
# p-значение:  0.06863667580021171
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1473
# p-значение:  0.06845895407225355
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1474
# p-значение:  0.06828150991613424
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1475
# p-значение:  0.06810434321805303
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1476
# p-значение:  0.0679274538641581
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1477
# p-значение:  0.0677508417405428
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1478
# p-значение:  0.06757450673324472
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1479
# p-значение:  0.06739844872824574
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1480
# p-значение:  0.06722266761146667
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1481
# p-значение:  0.06704716326876992
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1482
# p-значение:  0.0668719355859606
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1483
# p-значение:  0.06669698444877903
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1484
# p-значение:  0.06652230974290463
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1485
# p-значение:  0.06634791135394891
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1486
# p-значение:  0.06617378916746142
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1487
# p-значение:  0.0659999430689242
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1488
# p-значение:  0.06582637294375226
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1489
# p-значение:  0.06565307867728976
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1490
# p-значение:  0.06548006015481111
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1491
# p-значение:  0.0653073172615195
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1492
# p-значение:  0.06513484988254636
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1493
# p-значение:  0.06496265790294764
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1494
# p-значение:  0.064790741207706
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1495
# p-значение:  0.06461909968172486
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1496
# p-значение:  0.06444773320983299
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1497
# p-значение:  0.06427664167677838
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1498
# p-значение:  0.06410582496722994
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1499
# p-значение:  0.063935282965776
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1500
# p-значение:  0.06376501555692049
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1501
# p-значение:  0.0635950226250852
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1502
# p-значение:  0.06342530405460711
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1503
# p-значение:  0.06325585972973657
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1504
# p-значение:  0.06308668953463736
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1505
# p-значение:  0.06291779335338377
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1506
# p-значение:  0.06274917106996014
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1507
# p-значение:  0.06258082256826136
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1508
# p-значение:  0.06241274773208927
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1509
# p-значение:  0.06224494644515355
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1510
# p-значение:  0.062077418591066635
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1511
# p-значение:  0.06191016405334815
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1512
# p-значение:  0.06174318271541934
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1513
# p-значение:  0.06157647446060399
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1514
# p-значение:  0.06141003917212573
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1515
# p-значение:  0.06124387673310716
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1516
# p-значение:  0.061077987026570746
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1517
# p-значение:  0.06091236993543481
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1518
# p-значение:  0.060747025342514194
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1519
# p-значение:  0.06058195313051917
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1520
# p-значение:  0.06041715318204899
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1521
# p-значение:  0.06025262537960163
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1522
# p-значение:  0.06008836960556074
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1523
# p-значение:  0.059924385742202935
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1524
# p-значение:  0.05976067367169313
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1525
# p-значение:  0.0595972332760808
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1526
# p-значение:  0.05943406443730459
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1527
# p-значение:  0.05927116703718749
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1528
# p-значение:  0.05910854095743612
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1529
# p-значение:  0.05894618607963942
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1530
# p-значение:  0.05878410228526887
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1531
# p-значение:  0.05862228945567405
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1532
# p-значение:  0.058460747472085295
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1533
# p-значение:  0.05829947621561016
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1534
# p-значение:  0.05813847556723428
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1535
# p-значение:  0.05797774540781497
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1536
# p-значение:  0.05781728561808741
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1537
# p-значение:  0.05765709607865821
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1538
# p-значение:  0.0574971766700072
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1539
# p-значение:  0.057337527272483646
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1540
# p-значение:  0.05717814776630359
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1541
# p-значение:  0.05701903803155739
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1542
# p-значение:  0.05686019794819863
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1543
# p-значение:  0.05670162739604745
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1544
# p-значение:  0.05654332625478942
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1545
# p-значение:  0.056385294403970665
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1546
# p-значение:  0.056227531723003654
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1547
# p-значение:  0.05607003809115896
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1548
# p-значение:  0.055912813387568816
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1549
# p-значение:  0.05575585749122469
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1550
# p-значение:  0.05559917028097239
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1551
# p-значение:  0.05544275163551715
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1552
# p-значение:  0.05528660143341879
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1553
# p-значение:  0.05513071955309057
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1554
# p-значение:  0.054975105872798746
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1555
# p-значение:  0.05481976027066171
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1556
# p-значение:  0.054664682624646854
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1557
# p-значение:  0.05450987281257236
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1558
# p-значение:  0.05435533071210363
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1559
# p-значение:  0.05420105620075444
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1560
# p-значение:  0.054047049155880655
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1561
# p-значение:  0.05389330945468607
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1562
# p-значение:  0.053739836974216804
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1563
# p-значение:  0.05358663159136179
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1564
# p-значение:  0.05343369318284874
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1565
# p-значение:  0.05328102162524706
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1566
# p-значение:  0.05312861679496472
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1567
# p-значение:  0.05297647856824628
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1568
# p-значение:  0.05282460682117307
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1569
# p-значение:  0.05267300142966258
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1570
# p-значение:  0.05252166226946242
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1571
# p-значение:  0.05237058921615745
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1572
# p-значение:  0.052219782145160876
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1573
# p-значение:  0.05206924093171783
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1574
# p-значение:  0.051918965450902244
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1575
# p-значение:  0.05176895557761618
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1576
# p-значение:  0.0516192111865883
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1577
# p-значение:  0.05146973215237316
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1578
# p-значение:  0.051320518349349475
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1579
# p-значение:  0.05117156965172032
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1580
# p-значение:  0.0510228859335089
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1581
# p-значение:  0.050874467068559914
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1582
# p-значение:  0.05072631293053953
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1583
# p-значение:  0.05057842339293095
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1584
# p-значение:  0.05043079832903663
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1585
# p-значение:  0.05028343761197185
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1586
# p-значение:  0.050136341114668914
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными
# 1587
# p-значение:  0.04998950870987651
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1588
# p-значение:  0.04984294027015346
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1589
# p-значение:  0.049696635667870304
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1590
# p-значение:  0.049550594775206847
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1591
# p-значение:  0.049404817464154815
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1592
# p-значение:  0.04925930360651254
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1593
# p-значение:  0.04911405307388561
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1594
# p-значение:  0.048969065737686446
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1595
# p-значение:  0.04882434146912895
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1596
# p-значение:  0.048679880139233855
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1597
# p-значение:  0.048535681618822046
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1598
# p-значение:  0.04839174577851635
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1599
# p-значение:  0.04824807248873997
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1600
# p-значение:  0.04810466161971427
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1601
# p-значение:  0.04796151304145857
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1602
# p-значение:  0.04781862662378722
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1603
# p-значение:  0.047676002236312964
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1604
# p-значение:  0.04753363974844005
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1605
# p-значение:  0.047391539029366436
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1606
# p-значение:  0.04724969994808115
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1607
# p-значение:  0.04710812237336648
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1608
# p-значение:  0.046966806173790676
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1609
# p-значение:  0.04682575121771437
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1610
# p-значение:  0.04668495737328193
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1611
# p-значение:  0.04654442450842433
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1612
# p-значение:  0.04640415249085983
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1613
# p-значение:  0.046264141188087526
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1614
# p-значение:  0.046124390467391585
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1615
# p-значение:  0.0459849001958359
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1616
# p-значение:  0.04584567024026498
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1617
# p-значение:  0.045706700467303074
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1618
# p-значение:  0.045567990743350606
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1619
# p-значение:  0.04542954093458862
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1620
# p-значение:  0.04529135090696923
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1621
# p-значение:  0.04515342052622362
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1622
# p-значение:  0.045015749657852266
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1623
# p-значение:  0.044878338167131604
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1624
# p-значение:  0.044741185919105364
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1625
# p-значение:  0.044604292778592125
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1626
# p-значение:  0.044467658610173766
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1627
# p-значение:  0.04433128327820257
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1628
# p-значение:  0.04419516664679879
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1629
# p-значение:  0.0440593085798453
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1630
# p-значение:  0.043923708940992734
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1631
# p-значение:  0.043788367593649236
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1632
# p-значение:  0.04365328440099092
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1633
# p-значение:  0.04351845922594966
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1634
# p-значение:  0.04338389193122283
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1635
# p-значение:  0.043249582379262685
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1636
# p-значение:  0.043115530432275895
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1637
# p-значение:  0.04298173595223198
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1638
# p-значение:  0.042848198800850446
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1639
# p-значение:  0.04271491883960876
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1640
# p-значение:  0.0425818959297346
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1641
# p-значение:  0.04244912993220784
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1642
# p-значение:  0.04231662070775921
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1643
# p-значение:  0.042184368116868765
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1644
# p-значение:  0.042052372019766304
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1645
# p-значение:  0.041920632276426506
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1646
# p-значение:  0.041789148746573135
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1647
# p-значение:  0.041657921289671274
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1648
# p-значение:  0.04152694976493376
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1649
# p-значение:  0.04139623403131232
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1650
# p-значение:  0.04126577394750508
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1651
# p-значение:  0.04113556937194507
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1652
# p-значение:  0.04100562016280751
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1653
# p-значение:  0.040875926178007393
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1654
# p-значение:  0.04074648727519348
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1655
# p-значение:  0.04061730331175428
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1656
# p-значение:  0.040488374144809214
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1657
# p-значение:  0.04035969963121544
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1658
# p-значение:  0.04023127962755901
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1659
# p-значение:  0.040103113990160866
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1660
# p-значение:  0.039975202575071034
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1661
# p-значение:  0.03984754523806622
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1662
# p-значение:  0.039720141834655776
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1663
# p-значение:  0.03959299222007284
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1664
# p-значение:  0.03946609624927966
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1665
# p-значение:  0.039339453776959354
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1666
# p-значение:  0.039213064657523056
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1667
# p-значение:  0.039086928745101446
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1668
# p-значение:  0.038961045893546986
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1669
# p-значение:  0.03883541595643525
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1670
# p-значение:  0.03871003878705803
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1671
# p-значение:  0.038584914238426915
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1672
# p-значение:  0.03846004216326926
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1673
# p-значение:  0.03833542241403132
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1674
# p-значение:  0.038211054842870684
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1675
# p-значение:  0.0380869393016634
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1676
# p-значение:  0.03796307564199264
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1677
# p-значение:  0.03783946371515601
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1678
# p-значение:  0.037716103372163357
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1679
# p-значение:  0.03759299446373077
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1680
# p-значение:  0.03747013684028566
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1681
# p-значение:  0.0373475303519597
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1682
# p-значение:  0.03722517484859411
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1683
# p-значение:  0.03710307017973169
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1684
# p-значение:  0.03698121619462258
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1685
# p-значение:  0.03685961274221805
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1686
# p-значение:  0.03673825967116917
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1687
# p-значение:  0.03661715682983213
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1688
# p-значение:  0.036496304066259366
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1689
# p-значение:  0.03637570122820444
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1690
# p-значение:  0.03625534816311582
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1691
# p-значение:  0.03613524471814111
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1692
# p-значение:  0.036015390740120834
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1693
# p-значение:  0.03589578607559041
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1694
# p-значение:  0.03577643057078017
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1695
# p-значение:  0.03565732407161071
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1696
# p-значение:  0.03553846642369396
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1697
# p-значение:  0.03541985747233145
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1698
# p-значение:  0.03530149706251584
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1699
# p-значение:  0.035183385038924486
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1700
# p-значение:  0.035065521245924325
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1701
# p-значение:  0.034947905527566325
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1702
# p-значение:  0.03483053772758571
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1703
# p-значение:  0.0347134176894035
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1704
# p-значение:  0.03459654525612055
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1705
# p-значение:  0.03447992027052238
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1706
# p-значение:  0.03436354257507035
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1707
# p-значение:  0.03424741201190984
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1708
# p-значение:  0.03413152842286116
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1709
# p-значение:  0.034015891649424645
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1710
# p-значение:  0.03390050153277535
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1711
# p-значение:  0.03378535791376058
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1712
# p-значение:  0.03367046063290835
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1713
# p-значение:  0.033555809530413594
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1714
# p-значение:  0.033441404446147516
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1715
# p-значение:  0.03332724521964914
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1716
# p-значение:  0.03321333169012908
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1717
# p-значение:  0.03309966369646622
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1718
# p-значение:  0.032986241077206824
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1719
# p-значение:  0.03287306367056608
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1720
# p-значение:  0.03276013131442257
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1721
# p-значение:  0.032647443846320456
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1722
# p-значение:  0.032535001103466854
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1723
# p-значение:  0.03242280292273381
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1724
# p-значение:  0.032310849140652076
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1725
# p-значение:  0.03219913959341536
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1726
# p-значение:  0.03208767411687585
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1727
# p-значение:  0.03197645254654313
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1728
# p-значение:  0.031865474717587494
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1729
# p-значение:  0.031754740464832176
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1730
# p-значение:  0.03164424962275936
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1731
# p-значение:  0.03153400202550172
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1732
# p-значение:  0.0314239975068491
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1733
# p-значение:  0.03131423590024118
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1734
# p-значение:  0.031204717038771257
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1735
# p-значение:  0.031095440755181336
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1736
# p-значение:  0.030986406881862827
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1737
# p-значение:  0.030877615250857415
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1738
# p-значение:  0.030769065693851738
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1739
# p-значение:  0.030660758042181158
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1740
# p-значение:  0.030552692126824876
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1741
# p-значение:  0.030444867778406604
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1742
# p-значение:  0.03033728482719411
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1743
# p-значение:  0.030229943103096346
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1744
# p-значение:  0.030122842435666097
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1745
# p-значение:  0.030015982654093554
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1746
# p-значение:  0.029909363587211635
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1747
# p-значение:  0.02980298506348844
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1748
# p-значение:  0.029696846911032138
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1749
# p-значение:  0.029590948957585628
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1750
# p-значение:  0.029485291030529437
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1751
# p-значение:  0.02937987295687572
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1752
# p-значение:  0.029274694563271364
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1753
# p-значение:  0.029169755675997555
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1754
# p-значение:  0.029065056120964883
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1755
# p-значение:  0.028960595723716898
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1756
# p-значение:  0.028856374309423227
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1757
# p-значение:  0.028752391702886237
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1758
# p-значение:  0.02864864772853215
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1759
# p-значение:  0.028545142210418595
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1760
# p-значение:  0.028441874972226167
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1761
# p-значение:  0.02833884583725843
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1762
# p-значение:  0.02823605462844747
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1763
# p-значение:  0.028133501168344566
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1764
# p-значение:  0.02803118527912596
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1765
# p-значение:  0.027929106782586866
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1766
# p-значение:  0.02782726550014325
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1767
# p-значение:  0.02772566125283049
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1768
# p-значение:  0.027624293861301608
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1769
# p-значение:  0.02752316314582859
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1770
# p-значение:  0.02742226892629751
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1771
# p-значение:  0.027321611022212755
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1772
# p-значение:  0.027221189252689904
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1773
# p-значение:  0.02712100343646151
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1774
# p-значение:  0.027021053391869998
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1775
# p-значение:  0.02692133893687254
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1776
# p-значение:  0.026821859889033517
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1777
# p-значение:  0.026722616065529392
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1778
# p-значение:  0.026623607283146722
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1779
# p-значение:  0.02652483335827749
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1780
# p-значение:  0.026426294106923764
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1781
# p-значение:  0.02632798934469105
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1782
# p-значение:  0.026229918886793158
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1783
# p-значение:  0.026132082548045776
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1784
# p-значение:  0.026034480142870464
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1785
# p-значение:  0.02593711148529043
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1786
# p-значение:  0.025839976388928987
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1787
# p-значение:  0.025743074667013977
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1788
# p-значение:  0.02564640613237046
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1789
# p-значение:  0.025549970597424476
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1790
# p-значение:  0.02545376787419862
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1791
# p-значение:  0.025357797774315127
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1792
# p-значение:  0.02526206010899079
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1793
# p-значение:  0.02516655468903828
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1794
# p-значение:  0.0250712813248668
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1795
# p-значение:  0.024976239826477675
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1796
# p-значение:  0.024881430003465876
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1797
# p-значение:  0.02478685166501826
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1798
# p-значение:  0.02469250461991468
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1799
# p-значение:  0.02459838867652331
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1800
# p-значение:  0.02450450364280421
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1801
# p-значение:  0.024410849326303774
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1802
# p-значение:  0.02431742553415739
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1803
# p-значение:  0.024224232073089436
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1804
# p-значение:  0.02413126874940752
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1805
# p-значение:  0.024038535369007352
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1806
# p-значение:  0.023946031737367424
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1807
# p-значение:  0.023853757659551444
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1808
# p-значение:  0.02376171294020457
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1809
# p-значение:  0.023669897383556293
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1810
# p-значение:  0.02357831079341577
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1811
# p-значение:  0.02348695297317205
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1812
# p-значение:  0.023395823725796294
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1813
# p-значение:  0.02330492285383623
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1814
# p-значение:  0.02321425015941969
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1815
# p-значение:  0.02312380544425041
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1816
# p-значение:  0.02303358850960957
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1817
# p-значение:  0.0229435991563538
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1818
# p-значение:  0.022853837184913406
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1819
# p-значение:  0.022764302395295477
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1820
# p-значение:  0.022674994587078556
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1821
# p-значение:  0.022585913559413973
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1822
# p-значение:  0.02249705911102473
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1823
# p-значение:  0.022408431040206178
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1824
# p-значение:  0.02232002914482245
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1825
# p-значение:  0.022231853222308695
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 1826
# p-значение:  0.022143903069667736
# ...
# 2880
# p-значение:  3.36757288721401e-11
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2881
# p-значение:  3.0461411171245345e-11
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2882
# p-значение:  2.7531310564654632e-11
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2883
# p-значение:  2.486255645806068e-11
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2884
# p-значение:  2.2433388480180838e-11
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2885
# p-значение:  2.0224488750386627e-11
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2886
# p-значение:  1.821742756646927e-11
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2887
# p-значение:  1.6395107493849537e-11
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2888
# p-значение:  1.474198541018268e-11
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2889
# p-значение:  1.3243850460753492e-11
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2890
# p-значение:  1.1886935880056626e-11
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2891
# p-значение:  1.0659473304031053e-11
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2892
# p-значение:  9.549694368615746e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2893
# p-значение:  8.54760706658908e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2894
# p-значение:  7.643219390729428e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2895
# p-значение:  6.827871601444713e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2896
# p-значение:  6.093570092957634e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2897
# p-значение:  5.432987393305666e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2898
# p-значение:  4.839018075131207e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2899
# p-значение:  4.305444889496357e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2900
# p-значение:  3.8269387658829146e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2901
# p-значение:  3.397948589167754e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2902
# p-значение:  3.014033467252375e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2903
# p-значение:  2.6705304634333515e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2904
# p-значение:  2.3634427748220332e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2905
# p-значение:  2.0896617769494696e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2906
# p-значение:  1.84519066692701e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2907
# p-значение:  1.6275869541004795e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2908
# p-значение:  1.4341861032107772e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2909
# p-значение:  1.262101534393878e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2910
# p-значение:  1.1093348462054564e-12
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2911
# p-значение:  9.738876372011873e-13
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2912
# p-значение:  8.539835505416704e-13
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2913
# p-значение:  7.480682739924305e-13
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2914
# p-значение:  6.543654507140673e-13
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2915
# p-значение:  5.715428130770306e-13
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2916
# p-значение:  4.987121826616203e-13
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2917
# p-значение:  4.3454129183828627e-13
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2918
# p-значение:  3.781419621873283e-13
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2919
# p-значение:  3.2862601528904634e-13
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2920
# p-значение:  2.851052727237402e-13
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2921
# p-значение:  2.4713564528155985e-13
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2922
# p-значение:  2.1382895454280515e-13
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2923
# p-значение:  1.8474111129762605e-13
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2924
# p-значение:  1.5942802633617248e-13
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2925
# p-значение:  1.3744561044859438e-13
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2926
# p-значение:  1.1812772982011666e-13
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2927
# p-значение:  1.0147438445073931e-13
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2928
# p-значение:  8.704148513061227e-14
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2929
# p-значение:  7.460698725481052e-14
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2930
# p-значение:  6.372680161348399e-14
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2931
# p-значение:  5.440092820663267e-14
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2932
# p-значение:  4.6407322429331543e-14
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2933
# p-значение:  3.952393967665557e-14
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2934
# p-значение:  3.352873534367973e-14
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2935
# p-значение:  2.842170943040401e-14
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2936
# p-значение:  2.398081733190338e-14
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2937
# p-значение:  2.042810365310288e-14
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2938
# p-значение:  1.709743457922741e-14
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2939
# p-значение:  1.4432899320127035e-14
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2940
# p-значение:  1.2212453270876722e-14
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2941
# p-значение:  1.021405182655144e-14
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2942
# p-значение:  8.43769498715119e-15
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2943
# p-значение:  7.105427357601002e-15
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2944
# p-значение:  5.995204332975845e-15
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2945
# p-значение:  4.884981308350689e-15
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2946
# p-значение:  3.9968028886505635e-15
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2947
# p-значение:  3.3306690738754696e-15
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2948
# p-значение:  2.886579864025407e-15
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2949
# p-значение:  2.220446049250313e-15
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2950
# p-значение:  1.9984014443252818e-15
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2951
# p-значение:  1.5543122344752192e-15
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2952
# p-значение:  1.3322676295501878e-15
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2953
# p-значение:  1.1102230246251565e-15
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2954
# p-значение:  8.881784197001252e-16
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2955
# p-значение:  6.661338147750939e-16
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2956
# p-значение:  6.661338147750939e-16
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2957
# p-значение:  4.440892098500626e-16
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2958
# p-значение:  4.440892098500626e-16
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2959
# p-значение:  2.220446049250313e-16
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2960
# p-значение:  2.220446049250313e-16
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2961
# p-значение:  2.220446049250313e-16
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2962
# p-значение:  2.220446049250313e-16
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2963
# p-значение:  2.220446049250313e-16
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2964
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2965
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2966
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2967
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2968
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2969
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2970
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2971
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2972
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2973
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2974
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2975
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2976
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2977
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2978
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2979
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2980
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2981
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2982
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2983
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2984
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2985
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2986
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2987
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2988
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2989
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2990
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2991
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2992
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2993
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2994
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2995
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2996
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2997
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2998
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 2999
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3000
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3001
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3002
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3003
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3004
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3005
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3006
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3007
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3008
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3009
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3010
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3011
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3012
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3013
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3014
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3015
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3016
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3017
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3018
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3019
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3020
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3021
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3022
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3023
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3024
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3025
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3026
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3027
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3028
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3029
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3030
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3031
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3032
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3033
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3034
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3035
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3036
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3037
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3038
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3039
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3040
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3041
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3042
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3043
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3044
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3045
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3046
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3047
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3048
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
# 3049
# p-значение:  0.0
# Отвергаем нулевую гипотезу: между долями есть значимая разница
